# %% [markdown]
# <a href="https://colab.research.google.com/github/lesterlnds/CPE-018---Prelim-Exam/blob/main/Prelim_Exam_Landaos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image = cv2.imread("/content/circles.png")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (9,9), 2)
circles = cv2.HoughCircles(
    gray,
    cv2.HOUGH_GRADIENT,
    dp=1,
    minDist=150,
    param1=130,
    param2=50,
    minRadius=40,
    maxRadius=200
)
if circles is not None:
    circles = np.uint16(np.around(circles))
    for x, y, r in circles[0]:
        cv2.circle(image, (x, y), r, (0,0,255), 3)
cv2_imshow(image)
cv2.imwrite("/content/circles_detected.png", image)
# Out:
# <PIL.Image.Image image mode=RGB size=720x540>
# True
